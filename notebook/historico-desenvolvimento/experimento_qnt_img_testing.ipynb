# %%
import sys, os
sys.path.insert(0, os.path.abspath(".."))
from src import config

for classe in ["glioma", "meningioma", "notumor", "pituitary"]:
    pasta = os.path.join(config.TEST_DIR, classe)
    todos = os.listdir(pasta)
    imagens = [f for f in todos if f.lower().endswith((".jpg", ".jpeg", ".png"))]
    print(f"{classe}: {len(imagens)} imagens")
# Out:
# glioma: 400 imagens
# meningioma: 400 imagens
# notumor: 400 imagens
# pituitary: 400 imagens
