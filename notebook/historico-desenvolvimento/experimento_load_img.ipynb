# %%
import sys, os
sys.path.insert(0, os.path.abspath(".."))  # pra achar a pasta src/ um nivel acima

import matplotlib.pyplot as plt
from src.data_loader import load_images_from_folder
from src import config

X, y, class_names = load_images_from_folder(config.TRAIN_DIR)
print("Shape de X:", X.shape)
print("Classes:", class_names)

plt.imshow(X[0].reshape(config.IMG_SIZE, config.IMG_SIZE), cmap="gray")
plt.title(class_names[y[0]])
plt.show()
# Out:
# Shape de X: (5600, 4096)
# Classes: ['glioma', 'meningioma', 'notumor', 'pituitary']
